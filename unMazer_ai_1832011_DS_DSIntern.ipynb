# %% [markdown]
# ### DS INTERN TASK - 1832011_DS

# %% [markdown]
# ##### **Importing The Lbraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
listings_df = pd.read_csv('/content/listings.csv')
listings_df.head()
# Out:
#      id  ... availability_365
# 0  2265  ...              131
# 1  5245  ...                0
# 2  5456  ...              354
# 3  5636  ...               67
# 4  5769  ...               79
#
# [5 rows x 16 columns]

# %%
listings_df.shape
# Out:
# (10272, 16)

# %% [markdown]
# ##### **Geopandas and Geojson**

# %%
# !pip install geopandas

# %%
# !pip install geojsonio

# %% [markdown]
# ##### **TOP AREAS WITH HIGHEST NUMBER OF LISTING**

# %%
import geopandas as gpd

nhood_json = gpd.read_file('neighbourhoods.geojson')
nhood_json.head()
# Out:
#   neighbourhood  ...                                           geometry
# 0         78739  ...  MULTIPOLYGON (((-97.89002 30.20941, -97.88929 ...
# 1         78754  ...  MULTIPOLYGON (((-97.63658 30.40266, -97.63754 ...
# 2         78732  ...  MULTIPOLYGON (((-97.87303 30.43806, -97.87335 ...
# 3         78737  ...  MULTIPOLYGON (((-98.01876 30.24167, -98.01617 ...
# 4         78756  ...  MULTIPOLYGON (((-97.72792 30.32906, -97.72760 ...
#
# [5 rows x 3 columns]

# %%
nhood_json = nhood_json.sort_values('neighbourhood')
nhood_json.head()
# Out:
#    neighbourhood  ...                                           geometry
# 43         78701  ...  MULTIPOLYGON (((-97.73599 30.25101, -97.73589 ...
# 14         78702  ...  MULTIPOLYGON (((-97.69186 30.24848, -97.69172 ...
# 19         78703  ...  MULTIPOLYGON (((-97.76606 30.31295, -97.76482 ...
# 29         78704  ...  MULTIPOLYGON (((-97.75447 30.26507, -97.75410 ...
# 31         78705  ...  MULTIPOLYGON (((-97.72978 30.29871, -97.72893 ...
#
# [5 rows x 3 columns]

# %%
listings_df = listings_df.sort_values('neighbourhood')

# %%
sample_df = listings_df.groupby(['neighbourhood']).count()

# %%
sample_df.head()
# Out:
#                  id  name  ...  calculated_host_listings_count  availability_365
# neighbourhood              ...
# 78701           713   713  ...                             713               713
# 78702          1263  1263  ...                            1263              1263
# 78703           530   530  ...                             530               530
# 78704          1822  1822  ...                            1822              1822
# 78705           505   505  ...                             505               505
#
# [5 rows x 15 columns]

# %%
nhood_json['count'] = sample_df['id']
for i in range(len(nhood_json)):
  nhood_json['count'][i] = i

nhood_json
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#    neighbourhood  ... count
# 43         78701  ...  43.0
# 14         78702  ...  14.0
# 19         78703  ...  19.0
# 29         78704  ...  29.0
# 31         78705  ...  31.0
# 7          78712  ...   7.0
# 20         78717  ...  20.0
# 16         78719  ...  16.0
# 40         78721  ...  40.0
# 18         78722  ...  18.0
# 37         78723  ...  37.0
# 28         78724  ...  28.0
# 9          78725  ...   9.0
# 35         78726  ...  35.0
# 41         78727  ...  41.0
# 11         78728  ...  11.0
# 26         78729  ...  26.0
# 22         78730  ...  22.0
# 24         78731  ...  24.0
# ...

# %%
fig, ax = plt.subplots(1, figsize=(10, 10))
ax.axis('off')

fig = nhood_json.plot(column = 'count', cmap='twilight', linewidth=0.5, ax=ax, edgecolor='0.2', legend=True)

# %%
nhood_json = nhood_json.sort_values('count', ascending=False)

nhood_json.head(10)
# Out:
#    neighbourhood  ... count
# 43         78701  ...  43.0
# 42         78734  ...  42.0
# 41         78727  ...  41.0
# 40         78721  ...  40.0
# 39         78735  ...  39.0
# 38         78750  ...  38.0
# 37         78723  ...  37.0
# 36         78733  ...  36.0
# 35         78726  ...  35.0
# 34         78759  ...  34.0
#
# [10 rows x 4 columns]

# %% [markdown]
# ##### **Broken down by ROOM_TYPE**

# %%
sample_df1 = listings_df.copy()

# %%
sample_df1 = sample_df1.drop(['neighbourhood_group'], axis=1)
sample_df1
# Out:
#             id  ... availability_365
# 5026  24627763  ...              123
# 7988  41741178  ...                0
# 7984  41726188  ...               90
# 593    2273498  ...              326
# 6230  32516488  ...                0
# ...        ...  ...              ...
# 6504  33609676  ...              364
# 3626  19204907  ...              136
# 132     342243  ...              272
# 3769  20147722  ...              358
# 8548  43489523  ...              136
#
# [10272 rows x 15 columns]

# %%
merge = sample_df1.set_index('neighbourhood').join(nhood_json.set_index('neighbourhood'))

# %%
merge.head()
# Out:
#                      id  ... count
# neighbourhood            ...
# 78701          24627763  ...   NaN
# 78701          41741178  ...   NaN
# 78701          41726188  ...   NaN
# 78701           2273498  ...   NaN
# 78701          32516488  ...   NaN
#
# [5 rows x 17 columns]

# %%
fig, ax = plt.subplots(1, figsize=(10, 10))
ax.axis('off')

fig = merge.plot(column='room_type', cmap='viridis', linewidth=0.5, ax=ax, edgecolor='0.2', legend=True)

# %% [markdown]
# ##### **TOP 10 HOSTS BY THEIR TOTAL NUMBER OF LISTINGS**

# %%
sample_df2 = pd.DataFrame(listings_df['host_id'])
sample_df2['host_name'] = listings_df['host_name']

# %%
sample_df2 = sample_df2.drop_duplicates()

# %%
sample_df2 = sample_df2.sort_values('host_id')

# %%
sample_df2.reset_index(inplace = True)
sample_df2 = sample_df2.drop(['index'], axis=1)

# %%
sample_df2.head()
# Out:
#    host_id host_name
# 0       23  Charlene
# 1     2466     Paddy
# 2     2757    Olivia
# 3     4569     Glory
# 4     7148     Peggy

# %%
sample_df2.shape
# Out:
# (6773, 2)

# %%
sample_df3 = listings_df.copy()
sample_df3 = sample_df2.sort_values('host_name')

# %%
sample_df3 = listings_df.groupby(['host_id']).count()
sample_df3.reset_index(inplace = True)

# %%
sample_df3.head()
# Out:
#    host_id  id  ...  calculated_host_listings_count  availability_365
# 0       23   3  ...                               3                 3
# 1     2466   3  ...                               3                 3
# 2     2757   1  ...                               1                 1
# 3     4569   1  ...                               1                 1
# 4     7148   2  ...                               2                 2
#
# [5 rows x 16 columns]

# %%
sample_df3.shape
# Out:
# (6773, 16)

# %%
sample_df2['listing'] = sample_df3['id']
for i in range(4955):
  sample_df2['listing'][i] = sample_df3['id'][i]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
sample_df2 = sample_df2.sort_values('listing', ascending=False)

print('TOP 10 HOSTS BY THEIR TOTAL NUMBER OF LISTINGS')
sample_df.head(10)
# Out:
# TOP 10 HOSTS BY THEIR TOTAL NUMBER OF LISTINGS
#                  id  name  ...  calculated_host_listings_count  availability_365
# neighbourhood              ...
# 78701           713   713  ...                             713               713
# 78702          1263  1263  ...                            1263              1263
# 78703           530   530  ...                             530               530
# 78704          1822  1822  ...                            1822              1822
# 78705           505   505  ...                             505               505
# 78712             2     2  ...                               2                 2
# 78717            74    74  ...                              74                74
# 78719             4     4  ...                               4                 4
# 78721           204   204  ...                             204               204
# 78722           197   197  ...                             197               197
#
# ...
